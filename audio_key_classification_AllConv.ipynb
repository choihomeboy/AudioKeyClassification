# %%
import os

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from dataloader import KeyDataset
from torch.utils.data import DataLoader
from signal_process import signal_process
import warnings

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#Data paths
metadata_path = '../metadata.csv'
audio_dir = '../audio'

# example : ckpt/model.pth
ckpt_dir = 'ckpt'
best_saved_model = 'ResNet_LrDecay.pth'
if not os.path.exists(ckpt_dir):
    os.mkdir(ckpt_dir)
restore_path = os.path.join(ckpt_dir, best_saved_model)

# %%
#hyper_parameters
n_epochs = 300
batch_size = 16
num_label = 24
method = 'logmelspectrogram'
sr = 22050
learning_rate = 1e-3
momentum = 0.9
weight_decay=1e-4

# %%
# TODO : Build your model here
class AllConv(nn.Module):
    def __init__(self):
        super(AllConv, self).__init__()
        self.batch_norm1 = nn.BatchNorm2d(1)
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=20, kernel_size=5, stride=1)
        self.batch_norm2 = nn.BatchNorm2d(20)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=20, kernel_size=3, stride=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=1)
        self.batch_norm3 = nn.BatchNorm2d(20)
        self.conv3 = nn.Conv2d(in_channels=20, out_channels=40, kernel_size=3, stride=1)
        self.batch_norm4 = nn.BatchNorm2d(40)
        self.conv4 = nn.Conv2d(in_channels=40, out_channels=40, kernel_size=3, stride=1)
        self.batch_norm5 = nn.BatchNorm2d(40)

        self.conv5 = nn.Conv2d(in_channels=40, out_channels=80, kernel_size=3, stride=1)
        self.batch_norm6 = nn.BatchNorm2d(80)
        self.conv6 = nn.Conv2d(in_channels=80, out_channels=80, kernel_size=3, stride=1)
        self.batch_norm7 = nn.BatchNorm2d(80)
        self.conv7 = nn.Conv2d(in_channels=80, out_channels=160, kernel_size=3, stride=1)
        self.batch_norm8 = nn.BatchNorm2d(160)
        self.conv8 = nn.Conv2d(in_channels=160, out_channels=160, kernel_size=3, stride=1)
        self.batch_norm9 = nn.BatchNorm2d(160)
        self.conv9 = nn.Conv2d(in_channels=160, out_channels=24, kernel_size=1, stride=1)
        self.dropout = nn.Dropout(p=0.2)
        self.avgpool = nn.AdaptiveAvgPool2d((1,1))
        
    def forward(self, x):
        # print("연산 전", x.size())
        x = self.batch_norm1(x)
        x = F.elu(self.conv1(x))
        x = self.batch_norm2(x)
        x = F.elu(self.conv2(x))
        x = self.pool(x)
        x = self.dropout(x)

        x = self.batch_norm3(x)
        x = F.elu(self.conv3(x))
        x = self.batch_norm4(x)
        x = F.elu(self.conv4(x))
        x = self.pool(x)
        x = self.dropout(x)

        x = self.batch_norm5(x)
        x = F.elu(self.conv5(x))
        x = self.batch_norm6(x)
        x = F.elu(self.conv6(x))
        x = self.pool(x)
        x = self.dropout(x)

        x = self.batch_norm7(x)
        x = F.elu(self.conv7(x))
        x = self.dropout(x)
        
        x = self.batch_norm8(x)
        x = F.elu(self.conv8(x))
        x = self.dropout(x)

        x = self.batch_norm9(x)
        x = F.elu(self.conv9(x))
#         print(x.shape)
        x = self.avgpool(x)
#         print(x.shape)
        x = x.squeeze()
        
#         print("conv5 layer 연산 후", x.size())

#         print("차원 감소 후", x.size())
#         print("fc1 연산 후", x.size())

        return x

# %%
is_test_mode = False

if not is_test_mode:
    
    # Load Dataset and Dataloader
    train_dataset = KeyDataset(metadata_path=metadata_path, audio_dir=audio_dir, sr=sr, split='training')
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    valid_dataset = KeyDataset(metadata_path=metadata_path, audio_dir=audio_dir, sr=sr, split='validation')
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)
    model = AllConv()
#     model = DenseNet()
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=1e-3,momentum=0.9, weight_decay=1e-4)
    best_accuracy = 0

    # Training and Validation
    for epoch in range(n_epochs):
        
        model.train()

        train_correct = 0
        train_loss = 0
        i=0
        j=0
        for idx, (features, labels) in enumerate(train_loader):
            optimizer.zero_grad()
            features = signal_process(features, sr=sr, method=method).to(device)
            features = features.unsqueeze(1)
            labels = labels.to(device)
            
            output = model(features)
            loss = criterion(output, labels)
#             features = features.squeeze(1)
            train_loss += loss.item()

            loss.backward()
            optimizer.step()

            preds = output.argmax(dim=-1, keepdim=True)
            train_correct += (preds.squeeze() == labels).float().sum()
            if i%100 ==0:
                print(i)
            i+=1
        print("==== Epoch: %d, Train Loss: %.2f, Train Accuracy: %.3f" % (
            epoch, train_loss / len(train_loader), train_correct / len(train_dataset)))

        model.eval()

        valid_correct = 0
        valid_loss = 0

        for idx, (features, labels) in enumerate(valid_loader):
            features = signal_process(features, sr=sr, method=method).to(device)
            features = features.unsqueeze(1)
            labels = labels.to(device)

            output = model(features)
            loss = criterion(output, labels)
#             features = features.squeeze(1)
            valid_loss += loss.item()

            preds = output.argmax(dim=-1, keepdim=True)
            valid_correct += (preds.squeeze() == labels).float().sum()
            
        print("==== Epoch: %d, Valid Loss: %.2f, Valid Accuracy: %.3f" % (
            epoch, valid_loss / len(valid_loader), valid_correct / len(valid_dataset)))
        valid_accuracy = valid_correct/len(valid_dataset)

                
        if valid_accuracy> best_accuracy:
            best_accuracy = valid_accuracy
            torch.save(model.state_dict(), best_saved_model) # official recommended
            print('updated')
            

elif is_test_mode:

    # Load Dataset and Dataloader
    test_dataset = KeyDataset(metadata_path=metadata_path, audio_dir=audio_dir, sr=sr, split='test')
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Restore model
    model = torch.load(restore_path).to(device)
    print('==== Model restored : %s' % restore_path)

    test_correct = 0

    for features, labels in test_loader:
        features = signal_process(features, sr=sr, method=method).to(device)
        labels = labels.to(device)

        output = model(features)

        preds = output.argmax(dim=-1, keepdim=True)
        test_correct += (preds.squeeze() == labels).float().sum()

    print("=== Test accuracy: %.3f" % (test_correct / len(test_dataset)))
# Out:
# 0
# 100
# 200
# ==== Epoch: 0, Train Loss: 3.16, Train Accuracy: 0.070
# ==== Epoch: 0, Valid Loss: 3.12, Valid Accuracy: 0.081
# updated
# 0
# 100
# 200
# ==== Epoch: 1, Train Loss: 3.09, Train Accuracy: 0.092
# ==== Epoch: 1, Valid Loss: 3.14, Valid Accuracy: 0.095
# updated
# 0
# 100
# 200
# ==== Epoch: 2, Train Loss: 3.06, Train Accuracy: 0.097
# ==== Epoch: 2, Valid Loss: 3.11, Valid Accuracy: 0.094
# 0
# 100
# 200
# ==== Epoch: 3, Train Loss: 3.04, Train Accuracy: 0.101
# ==== Epoch: 3, Valid Loss: 3.07, Valid Accuracy: 0.103
# updated
# 0
# 100
# 200
# ==== Epoch: 4, Train Loss: 3.01, Train Accuracy: 0.118
# ==== Epoch: 4, Valid Loss: 3.02, Valid Accuracy: 0.099
# 0
# 100
# 200
# ==== Epoch: 5, Train Loss: 2.94, Train Accuracy: 0.142
# ==== Epoch: 5, Valid Loss: 2.89, Valid Accuracy: 0.143
# updated
# 0
# 100
# 200
# ==== Epoch: 6, Train Loss: 2.83, Train Accuracy: 0.195
# ==== Epoch: 6, Valid Loss: 2.72, Valid Accuracy: 0.207
# updated
# 0
# 100
# 200
# ==== Epoch: 7, Train Loss: 2.69, Train Accuracy: 0.245
# ==== Epoch: 7, Valid Loss: 2.57, Valid Accuracy: 0.261
# updated
# 0
# 100
# 200
# ==== Epoch: 8, Train Loss: 2.54, Train Accuracy: 0.279
# ==== Epoch: 8, Valid Loss: 2.44, Valid Accuracy: 0.278
# updated
# 0
# 100
# 200
# ==== Epoch: 9, Train Loss: 2.38, Train Accuracy: 0.327
# ==== Epoch: 9, Valid Loss: 2.35, Valid Accuracy: 0.311
# updated
# 0
# 100
# 200
# ==== Epoch: 10, Train Loss: 2.26, Train Accuracy: 0.360
# ==== Epoch: 10, Valid Loss: 2.19, Valid Accuracy: 0.361
# updated
# 0
# 100
# 200
# ==== Epoch: 11, Train Loss: 2.14, Train Accuracy: 0.403
# ==== Epoch: 11, Valid Loss: 2.10, Valid Accuracy: 0.373
# updated
# 0
# 100
# 200
# ==== Epoch: 12, Train Loss: 2.03, Train Accuracy: 0.436
# ==== Epoch: 12, Valid Loss: 1.97, Valid Accuracy: 0.404
# updated
# 0
# 100
# 200
# ==== Epoch: 13, Train Loss: 1.92, Train Accuracy: 0.457
# ==== Epoch: 13, Valid Loss: 1.92, Valid Accuracy: 0.433
# updated
# 0
# 100
# 200
# ==== Epoch: 14, Train Loss: 1.84, Train Accuracy: 0.484
# ==== Epoch: 14, Valid Loss: 1.88, Valid Accuracy: 0.430
# 0
# 100
# 200
# ==== Epoch: 15, Train Loss: 1.76, Train Accuracy: 0.507
# ==== Epoch: 15, Valid Loss: 1.77, Valid Accuracy: 0.458
# updated
# 0
# 100
# 200
# ==== Epoch: 16, Train Loss: 1.67, Train Accuracy: 0.533
# ==== Epoch: 16, Valid Loss: 1.68, Valid Accuracy: 0.471
# updated
# 0
# 100
# 200
# ==== Epoch: 17, Train Loss: 1.61, Train Accuracy: 0.542
# ==== Epoch: 17, Valid Loss: 1.65, Valid Accuracy: 0.487
# updated
# 0
# 100
# 200
# ==== Epoch: 18, Train Loss: 1.55, Train Accuracy: 0.556
# ==== Epoch: 18, Valid Loss: 1.54, Valid Accuracy: 0.539
# updated
# 0
# 100
# 200
# ==== Epoch: 19, Train Loss: 1.49, Train Accuracy: 0.581
# ==== Epoch: 19, Valid Loss: 1.56, Valid Accuracy: 0.549
# updated
# 0
# 100
# 200
# ==== Epoch: 20, Train Loss: 1.44, Train Accuracy: 0.588
# ==== Epoch: 20, Valid Loss: 1.49, Valid Accuracy: 0.564
# updated
# 0
# 100
# 200
# ==== Epoch: 21, Train Loss: 1.37, Train Accuracy: 0.606
# ==== Epoch: 21, Valid Loss: 1.48, Valid Accuracy: 0.555
# 0
# 100
# 200
# ==== Epoch: 22, Train Loss: 1.33, Train Accuracy: 0.630
# ==== Epoch: 22, Valid Loss: 1.39, Valid Accuracy: 0.580
# updated
# 0
# 100
# 200
# ==== Epoch: 23, Train Loss: 1.28, Train Accuracy: 0.642
# ==== Epoch: 23, Valid Loss: 1.40, Valid Accuracy: 0.577
# 0
# 100
# 200
# ==== Epoch: 24, Train Loss: 1.23, Train Accuracy: 0.654
# ==== Epoch: 24, Valid Loss: 1.41, Valid Accuracy: 0.580
# 0
# 100
# 200
# ==== Epoch: 25, Train Loss: 1.19, Train Accuracy: 0.672
# ==== Epoch: 25, Valid Loss: 1.34, Valid Accuracy: 0.603
# updated
# 0
# 100
# 200
# ==== Epoch: 26, Train Loss: 1.15, Train Accuracy: 0.676
# ==== Epoch: 26, Valid Loss: 1.32, Valid Accuracy: 0.583
# 0
# 100
# 200
# ==== Epoch: 27, Train Loss: 1.10, Train Accuracy: 0.685
# ==== Epoch: 27, Valid Loss: 1.27, Valid Accuracy: 0.607
# updated
# 0
# 100
# 200
# ==== Epoch: 28, Train Loss: 1.06, Train Accuracy: 0.709
# ==== Epoch: 28, Valid Loss: 1.22, Valid Accuracy: 0.635
# updated
# 0
# 100
# 200
# ==== Epoch: 29, Train Loss: 1.02, Train Accuracy: 0.715
# ==== Epoch: 29, Valid Loss: 1.31, Valid Accuracy: 0.591
# 0
# 100
# 200
# ==== Epoch: 30, Train Loss: 0.98, Train Accuracy: 0.727
# ==== Epoch: 30, Valid Loss: 1.16, Valid Accuracy: 0.657
# updated
# 0
# 100
# 200
# ==== Epoch: 31, Train Loss: 0.94, Train Accuracy: 0.744
# ==== Epoch: 31, Valid Loss: 1.24, Valid Accuracy: 0.621
# 0
# 100
# 200
# ==== Epoch: 32, Train Loss: 0.92, Train Accuracy: 0.752
# ==== Epoch: 32, Valid Loss: 1.21, Valid Accuracy: 0.620
# 0
# 100
# 200
# ==== Epoch: 33, Train Loss: 0.89, Train Accuracy: 0.760
# ==== Epoch: 33, Valid Loss: 1.17, Valid Accuracy: 0.646
# 0
# 100
# 200
# ==== Epoch: 34, Train Loss: 0.84, Train Accuracy: 0.772
# ==== Epoch: 34, Valid Loss: 1.18, Valid Accuracy: 0.653
# 0
# 100
# 200
# ==== Epoch: 35, Train Loss: 0.81, Train Accuracy: 0.785
# ==== Epoch: 35, Valid Loss: 1.16, Valid Accuracy: 0.648
# 0
# 100
# 200
# ==== Epoch: 36, Train Loss: 0.78, Train Accuracy: 0.791
# ==== Epoch: 36, Valid Loss: 1.16, Valid Accuracy: 0.632
# 0
# 100
# 200
# ==== Epoch: 37, Train Loss: 0.74, Train Accuracy: 0.809
# ==== Epoch: 37, Valid Loss: 1.09, Valid Accuracy: 0.665
# updated
# 0
# 100
# 200
# ==== Epoch: 38, Train Loss: 0.73, Train Accuracy: 0.814
# ==== Epoch: 38, Valid Loss: 1.09, Valid Accuracy: 0.681
# updated
# 0
# 100
# 200
# ==== Epoch: 39, Train Loss: 0.69, Train Accuracy: 0.821
# ==== Epoch: 39, Valid Loss: 1.01, Valid Accuracy: 0.678
# 0
# 100
# 200
# ==== Epoch: 40, Train Loss: 0.65, Train Accuracy: 0.836
# ==== Epoch: 40, Valid Loss: 1.07, Valid Accuracy: 0.686
# updated
# 0
# 100
# 200
# ==== Epoch: 41, Train Loss: 0.63, Train Accuracy: 0.838
# ==== Epoch: 41, Valid Loss: 1.03, Valid Accuracy: 0.670
# 0
# 100
# 200
# ==== Epoch: 42, Train Loss: 0.61, Train Accuracy: 0.846
# ==== Epoch: 42, Valid Loss: 0.97, Valid Accuracy: 0.702
# updated
# 0
# 100
# 200
# ==== Epoch: 43, Train Loss: 0.59, Train Accuracy: 0.854
# ==== Epoch: 43, Valid Loss: 0.98, Valid Accuracy: 0.696
# 0
# 100
# 200
# ==== Epoch: 44, Train Loss: 0.56, Train Accuracy: 0.860
# ==== Epoch: 44, Valid Loss: 0.96, Valid Accuracy: 0.720
# updated
# 0
# 100
# 200
# ==== Epoch: 45, Train Loss: 0.52, Train Accuracy: 0.874
# ==== Epoch: 45, Valid Loss: 0.95, Valid Accuracy: 0.716
# 0
# 100
# 200
# ==== Epoch: 46, Train Loss: 0.50, Train Accuracy: 0.878
# ==== Epoch: 46, Valid Loss: 1.00, Valid Accuracy: 0.689
# 0
# 100
# 200
# ==== Epoch: 47, Train Loss: 0.49, Train Accuracy: 0.887
# ==== Epoch: 47, Valid Loss: 0.87, Valid Accuracy: 0.716
# 0
# 100
# 200
# ==== Epoch: 48, Train Loss: 0.46, Train Accuracy: 0.893
# ==== Epoch: 48, Valid Loss: 0.90, Valid Accuracy: 0.726
# updated
# 0
# 100
# 200
# ==== Epoch: 49, Train Loss: 0.44, Train Accuracy: 0.908
# ==== Epoch: 49, Valid Loss: 0.93, Valid Accuracy: 0.724
# 0
# 100
# 200
# ==== Epoch: 50, Train Loss: 0.42, Train Accuracy: 0.906
# ==== Epoch: 50, Valid Loss: 0.89, Valid Accuracy: 0.743
# updated
# 0
# 100
# 200
# ==== Epoch: 51, Train Loss: 0.40, Train Accuracy: 0.906
# ==== Epoch: 51, Valid Loss: 1.02, Valid Accuracy: 0.714
# 0
# 100
# 200
# ==== Epoch: 52, Train Loss: 0.40, Train Accuracy: 0.915
# ==== Epoch: 52, Valid Loss: 0.97, Valid Accuracy: 0.706
# 0
# 100
# 200
# ==== Epoch: 53, Train Loss: 0.37, Train Accuracy: 0.920
# ==== Epoch: 53, Valid Loss: 0.84, Valid Accuracy: 0.744
# updated
# 0
# 100
# 200
# ==== Epoch: 54, Train Loss: 0.34, Train Accuracy: 0.932
# ==== Epoch: 54, Valid Loss: 0.83, Valid Accuracy: 0.768
# updated
# 0
# 100
# 200
# ==== Epoch: 55, Train Loss: 0.34, Train Accuracy: 0.931
# ==== Epoch: 55, Valid Loss: 0.86, Valid Accuracy: 0.750
# 0
# 100
# 200
# ==== Epoch: 56, Train Loss: 0.31, Train Accuracy: 0.938
# ==== Epoch: 56, Valid Loss: 0.84, Valid Accuracy: 0.752
# 0
# 100
# 200
# ==== Epoch: 57, Train Loss: 0.30, Train Accuracy: 0.944
# ==== Epoch: 57, Valid Loss: 0.87, Valid Accuracy: 0.747
# 0
# 100
# 200
# ==== Epoch: 58, Train Loss: 0.28, Train Accuracy: 0.947
# ==== Epoch: 58, Valid Loss: 0.83, Valid Accuracy: 0.773
# updated
# 0
# 100
# 200
# ==== Epoch: 59, Train Loss: 0.28, Train Accuracy: 0.948
# ==== Epoch: 59, Valid Loss: 0.80, Valid Accuracy: 0.771
# 0
# 100
# 200
# ==== Epoch: 60, Train Loss: 0.26, Train Accuracy: 0.947
# ==== Epoch: 60, Valid Loss: 0.79, Valid Accuracy: 0.752
# 0
# 100
# 200
# ==== Epoch: 61, Train Loss: 0.25, Train Accuracy: 0.960
# ==== Epoch: 61, Valid Loss: 0.82, Valid Accuracy: 0.766
# 0
# 100
# 200
# ==== Epoch: 62, Train Loss: 0.25, Train Accuracy: 0.955
# ==== Epoch: 62, Valid Loss: 0.85, Valid Accuracy: 0.755
# 0
# 100
# 200
# ==== Epoch: 63, Train Loss: 0.23, Train Accuracy: 0.959
# ==== Epoch: 63, Valid Loss: 0.78, Valid Accuracy: 0.768
# 0
# 100
# 200
# ==== Epoch: 64, Train Loss: 0.23, Train Accuracy: 0.958
# ==== Epoch: 64, Valid Loss: 0.81, Valid Accuracy: 0.759
# 0
# 100
# 200
# ==== Epoch: 65, Train Loss: 0.21, Train Accuracy: 0.969
# ==== Epoch: 65, Valid Loss: 0.81, Valid Accuracy: 0.764
# 0
# 100
# 200
# ==== Epoch: 66, Train Loss: 0.21, Train Accuracy: 0.967
# ==== Epoch: 66, Valid Loss: 0.82, Valid Accuracy: 0.763
# 0
# 100
# 200
# ==== Epoch: 67, Train Loss: 0.20, Train Accuracy: 0.967
# ==== Epoch: 67, Valid Loss: 0.76, Valid Accuracy: 0.778
# updated
# 0
# 100
# 200
# ==== Epoch: 68, Train Loss: 0.20, Train Accuracy: 0.967
# ==== Epoch: 68, Valid Loss: 0.93, Valid Accuracy: 0.739
# 0
# 100
# 200
# ==== Epoch: 69, Train Loss: 0.19, Train Accuracy: 0.969
# ==== Epoch: 69, Valid Loss: 0.79, Valid Accuracy: 0.791
# updated
# 0
# 100
# 200
# ==== Epoch: 70, Train Loss: 0.17, Train Accuracy: 0.976
# ==== Epoch: 70, Valid Loss: 0.75, Valid Accuracy: 0.788
# 0
# 100
# 200
# ==== Epoch: 71, Train Loss: 0.17, Train Accuracy: 0.974
# ==== Epoch: 71, Valid Loss: 0.79, Valid Accuracy: 0.785
# 0
# 100
# 200
# ==== Epoch: 72, Train Loss: 0.15, Train Accuracy: 0.979
# ==== Epoch: 72, Valid Loss: 0.76, Valid Accuracy: 0.782
# 0
# 100
# 200
# ==== Epoch: 73, Train Loss: 0.15, Train Accuracy: 0.983
# ==== Epoch: 73, Valid Loss: 0.75, Valid Accuracy: 0.781
# 0
# 100
# 200
# ==== Epoch: 74, Train Loss: 0.16, Train Accuracy: 0.977
# ==== Epoch: 74, Valid Loss: 0.75, Valid Accuracy: 0.797
# updated
# 0
# 100
# 200
# ==== Epoch: 75, Train Loss: 0.14, Train Accuracy: 0.980
# ==== Epoch: 75, Valid Loss: 0.78, Valid Accuracy: 0.781
# 0
# 100
# 200
# ==== Epoch: 76, Train Loss: 0.14, Train Accuracy: 0.982
# ==== Epoch: 76, Valid Loss: 0.74, Valid Accuracy: 0.779
# 0
# 100
# 200
# ==== Epoch: 77, Train Loss: 0.12, Train Accuracy: 0.988
# ==== Epoch: 77, Valid Loss: 0.69, Valid Accuracy: 0.801
# updated
# 0
# 100
# 200
# ==== Epoch: 78, Train Loss: 0.12, Train Accuracy: 0.986
# ==== Epoch: 78, Valid Loss: 0.71, Valid Accuracy: 0.795
# 0
# 100
# 200
# ==== Epoch: 79, Train Loss: 0.13, Train Accuracy: 0.985
# ==== Epoch: 79, Valid Loss: 0.74, Valid Accuracy: 0.795
# 0
# 100
# 200
# ==== Epoch: 80, Train Loss: 0.12, Train Accuracy: 0.988
# ==== Epoch: 80, Valid Loss: 0.69, Valid Accuracy: 0.804
# updated
# 0
# 100
# 200
# ==== Epoch: 81, Train Loss: 0.11, Train Accuracy: 0.990
# ==== Epoch: 81, Valid Loss: 0.68, Valid Accuracy: 0.807
# updated
# 0
# 100
# 200
# ==== Epoch: 82, Train Loss: 0.11, Train Accuracy: 0.989
# ==== Epoch: 82, Valid Loss: 0.74, Valid Accuracy: 0.800
# 0
# 100
# 200
# ==== Epoch: 83, Train Loss: 0.11, Train Accuracy: 0.986
# ==== Epoch: 83, Valid Loss: 0.69, Valid Accuracy: 0.811
# updated
# 0
# 100
# 200
# ==== Epoch: 84, Train Loss: 0.12, Train Accuracy: 0.985
# ==== Epoch: 84, Valid Loss: 0.64, Valid Accuracy: 0.814
# updated
# 0
# 100
# 200
# ==== Epoch: 85, Train Loss: 0.10, Train Accuracy: 0.991
# ==== Epoch: 85, Valid Loss: 0.73, Valid Accuracy: 0.795
# 0
# 100
# 200
# ==== Epoch: 86, Train Loss: 0.10, Train Accuracy: 0.989
# ==== Epoch: 86, Valid Loss: 0.72, Valid Accuracy: 0.796
# 0
# 100
# 200
# ==== Epoch: 87, Train Loss: 0.11, Train Accuracy: 0.986
# ==== Epoch: 87, Valid Loss: 0.71, Valid Accuracy: 0.793
# 0
# 100
# 200
# ==== Epoch: 88, Train Loss: 0.10, Train Accuracy: 0.991
# ==== Epoch: 88, Valid Loss: 0.73, Valid Accuracy: 0.788
# 0
# 100
# 200
# ==== Epoch: 89, Train Loss: 0.11, Train Accuracy: 0.988
# ==== Epoch: 89, Valid Loss: 0.68, Valid Accuracy: 0.812
# 0
# 100
# 200
# ==== Epoch: 90, Train Loss: 0.11, Train Accuracy: 0.985
# ==== Epoch: 90, Valid Loss: 0.70, Valid Accuracy: 0.812
# 0
# 100
# 200
# ==== Epoch: 91, Train Loss: 0.08, Train Accuracy: 0.994
# ==== Epoch: 91, Valid Loss: 0.63, Valid Accuracy: 0.811
# 0
# 100
# 200
# ==== Epoch: 92, Train Loss: 0.08, Train Accuracy: 0.991
# ==== Epoch: 92, Valid Loss: 0.66, Valid Accuracy: 0.821
# updated
# 0
# 100
# 200
# ==== Epoch: 93, Train Loss: 0.08, Train Accuracy: 0.994
# ==== Epoch: 93, Valid Loss: 0.72, Valid Accuracy: 0.797
# 0
# 100
# 200
# ==== Epoch: 94, Train Loss: 0.07, Train Accuracy: 0.993
# ==== Epoch: 94, Valid Loss: 0.64, Valid Accuracy: 0.823
# updated
# 0
# 100
# 200
# ==== Epoch: 95, Train Loss: 0.07, Train Accuracy: 0.994
# ==== Epoch: 95, Valid Loss: 0.68, Valid Accuracy: 0.806
# 0
# 100
# 200
# ==== Epoch: 96, Train Loss: 0.07, Train Accuracy: 0.994
# ==== Epoch: 96, Valid Loss: 0.66, Valid Accuracy: 0.817
# 0
# 100
# 200
# ==== Epoch: 97, Train Loss: 0.07, Train Accuracy: 0.994
# ==== Epoch: 97, Valid Loss: 0.69, Valid Accuracy: 0.798
# 0
# 100
# 200
# ==== Epoch: 98, Train Loss: 0.08, Train Accuracy: 0.994
# ==== Epoch: 98, Valid Loss: 0.68, Valid Accuracy: 0.817
# 0
# 100
# 200
# ==== Epoch: 99, Train Loss: 0.08, Train Accuracy: 0.994
# ==== Epoch: 99, Valid Loss: 0.69, Valid Accuracy: 0.816
# 0
# 100
# 200
# ==== Epoch: 100, Train Loss: 0.07, Train Accuracy: 0.993
# ==== Epoch: 100, Valid Loss: 0.63, Valid Accuracy: 0.816
# 0
# 100
# 200
# ==== Epoch: 101, Train Loss: 0.06, Train Accuracy: 0.996
# ==== Epoch: 101, Valid Loss: 0.66, Valid Accuracy: 0.812
# 0
# 100
# 200
# ==== Epoch: 102, Train Loss: 0.08, Train Accuracy: 0.991
# ==== Epoch: 102, Valid Loss: 0.65, Valid Accuracy: 0.820
# 0
# 100
# 200
# ==== Epoch: 103, Train Loss: 0.08, Train Accuracy: 0.991
# ==== Epoch: 103, Valid Loss: 0.69, Valid Accuracy: 0.810
# 0
# 100
# 200
# ==== Epoch: 104, Train Loss: 0.06, Train Accuracy: 0.994
# ==== Epoch: 104, Valid Loss: 0.66, Valid Accuracy: 0.824
# updated
# 0
# 100
# 200
# ==== Epoch: 105, Train Loss: 0.06, Train Accuracy: 0.997
# ==== Epoch: 105, Valid Loss: 0.62, Valid Accuracy: 0.825
# updated
# 0
# 100
# 200
# ==== Epoch: 106, Train Loss: 0.06, Train Accuracy: 0.995
# ==== Epoch: 106, Valid Loss: 0.70, Valid Accuracy: 0.807
# 0
# 100
# 200
# ==== Epoch: 107, Train Loss: 0.06, Train Accuracy: 0.996
# ==== Epoch: 107, Valid Loss: 0.62, Valid Accuracy: 0.834
# updated
# 0
# 100
# 200
# ==== Epoch: 108, Train Loss: 0.05, Train Accuracy: 0.996
# ==== Epoch: 108, Valid Loss: 0.63, Valid Accuracy: 0.826
# 0
# 100
# 200
# ==== Epoch: 109, Train Loss: 0.05, Train Accuracy: 0.996
# ==== Epoch: 109, Valid Loss: 0.68, Valid Accuracy: 0.824
# 0
# 100
# 200
# ==== Epoch: 110, Train Loss: 0.05, Train Accuracy: 0.996
# ==== Epoch: 110, Valid Loss: 0.67, Valid Accuracy: 0.820
# 0
# 100
# 200
# ==== Epoch: 111, Train Loss: 0.05, Train Accuracy: 0.997
# ==== Epoch: 111, Valid Loss: 0.59, Valid Accuracy: 0.847
# updated
# 0
# 100
# 200
# ==== Epoch: 112, Train Loss: 0.04, Train Accuracy: 0.998
# ==== Epoch: 112, Valid Loss: 0.63, Valid Accuracy: 0.826
# 0
# 100
# 200
# ==== Epoch: 113, Train Loss: 0.05, Train Accuracy: 0.996
# ==== Epoch: 113, Valid Loss: 0.62, Valid Accuracy: 0.842
# 0
# 100
# 200
# ==== Epoch: 114, Train Loss: 0.04, Train Accuracy: 0.999
# ==== Epoch: 114, Valid Loss: 0.64, Valid Accuracy: 0.837
# 0
# 100
# 200
# ==== Epoch: 115, Train Loss: 0.05, Train Accuracy: 0.997
# ==== Epoch: 115, Valid Loss: 0.65, Valid Accuracy: 0.828
# 0
# 100
# 200
# ==== Epoch: 116, Train Loss: 0.06, Train Accuracy: 0.997
# ==== Epoch: 116, Valid Loss: 0.66, Valid Accuracy: 0.829
# 0
# 100
# 200
# ==== Epoch: 117, Train Loss: 0.04, Train Accuracy: 0.997
# ==== Epoch: 117, Valid Loss: 0.67, Valid Accuracy: 0.820
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-7fadb3cd551a> in <module>
#      27         for idx, (features, labels) in enumerate(train_loader):
#      28             optimizer.zero_grad()
# ---> 29             features = signal_process(features, sr=sr, method=method).to(device)
#      30             features = features.unsqueeze(1)
#      31             labels = labels.to(device)
#
# ~/gisan_project1/yongwoo/signal_process.py in signal_process(audio_samples, sr, method)
#      37     elif method == 'logmelspectrogram':
#      38         mel_layer = torchaudio.transforms.MelSpectrogram(sample_rate=22050, n_fft=2048, hop_length=1024, normalized=True)
# ---> 39         mel_spec = mel_layer(audio_samples)
#      40         log_mel = torch.log(torch.clamp(mel_spec, min=1e-6))
#      41         return log_mel
#
# ~/[/anaconda3]/envs/gisan/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/[/anaconda3]/envs/gisan/lib/python3.7/site-packages/torchaudio/transforms.py in forward(self, waveform)
#     424             Tensor: Mel frequency spectrogram of size (..., ``n_mels``, time).
#     425         """
# --> 426         specgram = self.spectrogram(waveform)
#     427         mel_specgram = self.mel_scale(specgram)
#     428         return mel_specgram
#
# ~/[/anaconda3]/envs/gisan/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/[/anaconda3]/envs/gisan/lib/python3.7/site-packages/torchaudio/transforms.py in forward(self, waveform)
#      82         """
#      83         return F.spectrogram(waveform, self.pad, self.window, self.n_fft, self.hop_length,
# ---> 84                              self.win_length, self.power, self.normalized)
#      85
#      86
#
# ~/[/anaconda3]/envs/gisan/lib/python3.7/site-packages/torchaudio/functional.py in spectrogram(waveform, pad, window, n_fft, hop_length, win_length, power, normalized)
#     160     # default values are consistent with librosa.core.spectrum._spectrogram
#     161     spec_f = torch.stft(
# --> 162         waveform, n_fft, hop_length, win_length, window, True, "reflect", False, True
#     163     )
#     164
#
# ~/[/anaconda3]/envs/gisan/lib/python3.7/site-packages/torch/functional.py in stft(input, n_fft, hop_length, win_length, window, center, pad_mode, normalized, onesided)
#     461         extended_shape = [1] * (3 - signal_dim) + list(input.size())
#     462         pad = int(n_fft // 2)
# --> 463         input = F.pad(input.view(extended_shape), (pad, pad), pad_mode)
#     464         input = input.view(input.shape[-signal_dim:])
#     465     return _VF.stft(input, n_fft, hop_length, win_length, window, normalized, onesided)
#
# ~/[/anaconda3]/envs/gisan/lib/python3.7/site-packages/torch/nn/functional.py in _pad(input, pad, mode, value)
#    3556             assert len(pad) == 2, '3D tensors expect 2 values for padding'
#    3557             if mode == 'reflect':
# -> 3558                 return torch._C._nn.reflection_pad1d(input, pad)
#    3559             elif mode == 'replicate':
#    3560                 return torch._C._nn.replication_pad1d(input, pad)
#
# KeyboardInterrupt:

# %%
resnet_lrdecay
